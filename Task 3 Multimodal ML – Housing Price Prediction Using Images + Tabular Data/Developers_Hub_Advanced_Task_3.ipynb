# %%
# !git clone https://github.com/emanhamed/Houses-dataset.git
# Out:
# Cloning into 'Houses-dataset'...
# remote: Enumerating objects: 2166, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 2166 (delta 0), reused 0 (delta 0), pack-reused 2165 (from 1)
# Receiving objects: 100% (2166/2166), 176.26 MiB | 22.67 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# import the necessary packages
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import glob
import cv2
import os

def load_house_attributes(inputPath):
	# initialize the list of column names in the CSV file and then
	# load it using Pandas
	cols = ["bedrooms", "bathrooms", "area", "zipcode", "price"]
	df = pd.read_csv(inputPath, sep=" ", header=None, names=cols)

	# determine (1) the unique zip codes and (2) the number of data
	# points with each zip code
	zipcodes = df["zipcode"].value_counts().keys().tolist()
	counts = df["zipcode"].value_counts().tolist()

	# loop over each of the unique zip codes and their corresponding
	# count
	for (zipcode, count) in zip(zipcodes, counts):
		# the zip code counts for our housing dataset is *extremely*
		# unbalanced (some only having 1 or 2 houses per zip code)
		# so let's sanitize our data by removing any houses with less
		# than 25 houses per zip code
		if count < 25:
			idxs = df[df["zipcode"] == zipcode].index
			df.drop(idxs, inplace=True)

	# return the data frame
	return df

def process_house_attributes(df, train, test):
	# initialize the column names of the continuous data
	continuous = ["bedrooms", "bathrooms", "area"]

	# performin min-max scaling each continuous feature column to
	# the range [0, 1]
	cs = MinMaxScaler()
	trainContinuous = cs.fit_transform(train[continuous])
	testContinuous = cs.transform(test[continuous])

	# one-hot encode the zip code categorical data (by definition of
	# one-hot encoing, all output features are now in the range [0, 1])
	zipBinarizer = LabelBinarizer().fit(df["zipcode"])
	trainCategorical = zipBinarizer.transform(train["zipcode"])
	testCategorical = zipBinarizer.transform(test["zipcode"])

	# construct our training and testing data points by concatenating
	# the categorical features with the continuous features
	trainX = np.hstack([trainCategorical, trainContinuous])
	testX = np.hstack([testCategorical, testContinuous])

	# return the concatenated training and testing data
	return (trainX, testX)

def load_house_images(df, inputPath):
	# initialize our images array (i.e., the house images themselves)
	images = []

	# loop over the indexes of the houses
	for i in df.index.values:
		# find the four images for the house and sort the file paths,
		# ensuring the four are always in the *same order*
		basePath = os.path.sep.join([inputPath, "{}_*".format(i + 1)])
		housePaths = sorted(list(glob.glob(basePath)))

		# initialize our list of input images along with the output image
		# after *combining* the four input images
		inputImages = []
		outputImage = np.zeros((64, 64, 3), dtype="uint8")

		# loop over the input house paths
		for housePath in housePaths:
			# load the input image, resize it to be 32 32, and then
			# update the list of input images
			image = cv2.imread(housePath)
			image = cv2.resize(image, (32, 32))
			inputImages.append(image)

		# tile the four input images in the output image such the first
		# image goes in the top-right corner, the second image in the
		# top-left corner, the third image in the bottom-right corner,
		# and the final image in the bottom-left corner
		outputImage[0:32, 0:32] = inputImages[0]
		outputImage[0:32, 32:64] = inputImages[1]
		outputImage[32:64, 32:64] = inputImages[2]
		outputImage[32:64, 0:32] = inputImages[3]

		# add the tiled image to our set of images the network will be
		# trained on
		images.append(outputImage)

	# return our set of images
	return np.array(images)

# %%
# import the necessary packages
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import numpy as np
import os

# construct the path to the input .txt file that contains information
# on each house in the dataset and then load the dataset
print("[INFO] loading house attributes...")
inputPath = os.path.sep.join(["/content/Houses-dataset/Houses Dataset","HousesInfo.txt"])
df = load_house_attributes(inputPath)
# Out:
# [INFO] loading house attributes...

# %%
# load the house images and then scale the pixel intensities to the
# range [0, 1]
print("[INFO] loading house images...")
images = load_house_images(df, "/content/Houses-dataset/Houses Dataset")
images = images / 255.0
# Out:
# [INFO] loading house images...

# %%
# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
split = train_test_split(df, images, test_size=0.25, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split

# %%
# find the largest house price in the training set and use it to
# scale our house prices to the range [0, 1] (will lead to better
# training and convergence)
maxPrice = trainAttrX["price"].max()
trainY = trainAttrX["price"] / maxPrice
testY = testAttrX["price"] / maxPrice

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers import BatchNormalization # Corrected import
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Activation
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Input
from keras.models import Model

def create_mlp(dim, regress=False):
        # define our MLP network
        model = Sequential()
        model.add(Dense(8, input_dim=dim, activation="relu"))
        model.add(Dense(4, activation="relu"))

        # check to see if the regression node should be added
        if regress:
                model.add(Dense(1, activation="linear"))

        # return our model
        return model

def create_cnn(width, height, depth, filters=(16, 32, 64), regress=False):
        # initialize the input shape and channel dimension, assuming
        # TensorFlow/channels-last ordering
        inputShape = (height, width, depth)
        chanDim = -1

        # define the model input
        inputs = Input(shape=inputShape)

        # loop over the number of filters
        for (i, f) in enumerate(filters):
                # if this is the first CONV layer then set the input
                # appropriately
                if i == 0:
                        x = inputs

                # CONV => RELU => BN => POOL
                x = Conv2D(f, (3, 3), padding="same")(x)
                x = Activation("relu")(x)
                x = BatchNormalization(axis=chanDim)(x)
                x = MaxPooling2D(pool_size=(2, 2))(x)

        # flatten the volume, then FC => RELU => BN => DROPOUT
        x = Flatten()(x)
        x = Dense(16)(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=chanDim)(x)
        x = Dropout(0.5)(x)

        # apply another FC layer, this one to match the number of nodes
        # coming out of the MLP
        x = Dense(4)(x)
        x = Activation("relu")(x)

        # check to see if the regression node should be added
        if regress:
                x = Dense(1, activation="linear")(x)

        # construct the CNN
        model = Model(inputs, x)

        # return the CNN
        return model

# %%
# create our Convolutional Neural Network and then compile the model
# using mean absolute percentage error as our loss, implying that we
# seek to minimize the absolute percentage difference between our
# price *predictions* and the *actual prices*
model = create_cnn(64, 64, 3, regress=True)
opt = Adam(learning_rate=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt)

# %%
# train the model
print("[INFO] training model...")
model.fit(trainImagesX, trainY, validation_data=(testImagesX, testY),
	epochs=200, batch_size=8)
# Out:
# [INFO] training model...
# Epoch 1/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - loss: 1444.0156 - val_loss: 247.9653
# Epoch 2/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 1069.2313 - val_loss: 1001.5798
# Epoch 3/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 741.5058 - val_loss: 1337.1615
# Epoch 4/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 626.2635 - val_loss: 1500.5873
# Epoch 5/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 602.0495 - val_loss: 2111.2271
# Epoch 6/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 367.7667 - val_loss: 3474.8621
# Epoch 7/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 326.5372 - val_loss: 3315.2688
# Epoch 8/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 300.6146 - val_loss: 3260.8809
# Epoch 9/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 188.0599 - val_loss: 2355.8870
# Epoch 10/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 177.3092 - val_loss: 2257.1841
# Epoch 11/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 220.1439 - val_loss: 716.1048
# Epoch 12/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 206.0878 - val_loss: 206.3960
# Epoch 13/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 166.8548 - val_loss: 99.8942
# Epoch 14/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 134.1257 - val_loss: 72.0847
# Epoch 15/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 130.1308 - val_loss: 77.8559
# Epoch 16/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 127.7430 - val_loss: 69.0072
# Epoch 17/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 120.1018 - val_loss: 74.5006
# Epoch 18/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 115.6844 - val_loss: 75.0128
# Epoch 19/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 116.2579 - val_loss: 68.4796
# Epoch 20/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 86.8593 - val_loss: 67.2561
# Epoch 21/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 110.8954 - val_loss: 64.6212
# Epoch 22/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 105.7388 - val_loss: 83.1865
# Epoch 23/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 113.9045 - val_loss: 74.1960
# Epoch 24/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 99.5176 - val_loss: 75.9607
# Epoch 25/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 90.4813 - val_loss: 66.8308
# Epoch 26/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 94.9691 - val_loss: 66.1947
# Epoch 27/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 85.3532 - val_loss: 70.6675
# Epoch 28/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 82.1220 - val_loss: 71.9335
# Epoch 29/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 71.8997 - val_loss: 68.2470
# Epoch 30/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 66.3909 - val_loss: 68.2384
# Epoch 31/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 81.3159 - val_loss: 65.8757
# Epoch 32/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 67.8246 - val_loss: 76.0796
# Epoch 33/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 86.3606 - val_loss: 68.7461
# Epoch 34/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 72.8980 - val_loss: 71.8574
# Epoch 35/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 71.2885 - val_loss: 73.8632
# Epoch 36/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 70.9869 - val_loss: 70.9220
# Epoch 37/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 66.7820 - val_loss: 70.5980
# Epoch 38/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 67.0498 - val_loss: 67.9297
# Epoch 39/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 60.8463 - val_loss: 71.0379
# Epoch 40/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 78.7003 - val_loss: 70.8602
# Epoch 41/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 68.1835 - val_loss: 69.6551
# Epoch 42/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 68.0416 - val_loss: 68.5536
# Epoch 43/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 67.4383 - val_loss: 68.3001
# Epoch 44/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 66.1864 - val_loss: 67.2816
# Epoch 45/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 66.4282 - val_loss: 67.2875
# Epoch 46/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 60.2684 - val_loss: 63.7176
# Epoch 47/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 65.1913 - val_loss: 63.7684
# Epoch 48/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 72.2852 - val_loss: 64.8264
# Epoch 49/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 64.9397 - val_loss: 63.0229
# Epoch 50/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 66.4553 - val_loss: 61.9789
# Epoch 51/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 61.8673 - val_loss: 61.7646
# Epoch 52/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 68.9681 - val_loss: 63.4801
# Epoch 53/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 66.5841 - val_loss: 64.5261
# Epoch 54/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 63.6721 - val_loss: 66.2307
# Epoch 55/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 67.8882 - val_loss: 64.0036
# Epoch 56/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 66.2792 - val_loss: 64.3579
# Epoch 57/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 61.0486 - val_loss: 65.7636
# Epoch 58/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 62.2487 - val_loss: 65.7975
# Epoch 59/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 64.4089 - val_loss: 67.4589
# Epoch 60/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 66.8881 - val_loss: 68.3915
# Epoch 61/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 65.0031 - val_loss: 67.5345
# Epoch 62/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 66.5777 - val_loss: 67.2584
# Epoch 63/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 59.9884 - val_loss: 66.9537
# Epoch 64/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 65.9832 - val_loss: 67.0397
# Epoch 65/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 57.9741 - val_loss: 67.0855
# Epoch 66/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 60.6533 - val_loss: 67.0850
# Epoch 67/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 60.4699 - val_loss: 64.7861
# Epoch 68/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 67.3815 - val_loss: 65.2083
# Epoch 69/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 62.0419 - val_loss: 66.3339
# Epoch 70/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 67.6926 - val_loss: 65.8670
# Epoch 71/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 63.0526 - val_loss: 68.3141
# Epoch 72/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 58.3146 - val_loss: 67.5645
# Epoch 73/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 62.2509 - val_loss: 64.0739
# Epoch 74/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 59.1586 - val_loss: 62.8015
# Epoch 75/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 52.3959 - val_loss: 64.4269
# Epoch 76/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 61.4422 - val_loss: 58.9332
# Epoch 77/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 57.4753 - val_loss: 61.2100
# Epoch 78/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 61.5942 - val_loss: 56.0811
# Epoch 79/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 55.2508 - val_loss: 55.4549
# Epoch 80/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 53.2816 - val_loss: 54.8122
# Epoch 81/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 58.0139 - val_loss: 64.4165
# Epoch 82/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 56.3996 - val_loss: 58.4628
# Epoch 83/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 56.8295 - val_loss: 63.1608
# Epoch 84/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 58.4192 - val_loss: 65.3130
# Epoch 85/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 59.9039 - val_loss: 65.1714
# Epoch 86/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 55.3658 - val_loss: 65.0237
# Epoch 87/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 52.1365 - val_loss: 63.1034
# Epoch 88/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 54.1890 - val_loss: 60.7671
# Epoch 89/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 49.8709 - val_loss: 69.0154
# Epoch 90/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 52.1899 - val_loss: 65.8927
# Epoch 91/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 51.6946 - val_loss: 58.0608
# Epoch 92/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 52.8902 - val_loss: 57.0998
# Epoch 93/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 52.6543 - val_loss: 63.6434
# Epoch 94/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 48.7615 - val_loss: 61.8599
# Epoch 95/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 49.7437 - val_loss: 71.9681
# Epoch 96/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 53.5568 - val_loss: 59.9461
# Epoch 97/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 48.5654 - val_loss: 80.1043
# Epoch 98/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 51.1733 - val_loss: 84.8838
# Epoch 99/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 49.5735 - val_loss: 76.6527
# Epoch 100/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 47.1228 - val_loss: 70.2433
# Epoch 101/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 53.6710 - val_loss: 64.0929
# Epoch 102/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 50.2916 - val_loss: 68.1505
# Epoch 103/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 48.7356 - val_loss: 64.7382
# Epoch 104/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 48.9067 - val_loss: 64.4423
# Epoch 105/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 43.4737 - val_loss: 68.3495
# Epoch 106/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 50.2675 - val_loss: 61.0314
# Epoch 107/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 50.2583 - val_loss: 60.4587
# Epoch 108/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 41.6171 - val_loss: 59.9470
# Epoch 109/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 43.8994 - val_loss: 65.0587
# Epoch 110/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 46.4775 - val_loss: 59.8730
# Epoch 111/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 39.6625 - val_loss: 64.1095
# Epoch 112/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 40.1242 - val_loss: 75.5726
# Epoch 113/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 39.8871 - val_loss: 86.3271
# Epoch 114/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 40.2939 - val_loss: 58.5291
# Epoch 115/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 39.8331 - val_loss: 64.8638
# Epoch 116/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 46.5108 - val_loss: 95.9139
# Epoch 117/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 39.7533 - val_loss: 68.2686
# Epoch 118/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 41.5037 - val_loss: 69.5807
# Epoch 119/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 42.0370 - val_loss: 71.5294
# Epoch 120/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 43.9312 - val_loss: 70.6970
# Epoch 121/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 38.7194 - val_loss: 53.2768
# Epoch 122/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 37.3879 - val_loss: 57.2341
# Epoch 123/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 34.3969 - val_loss: 58.9212
# Epoch 124/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 40.3278 - val_loss: 50.4815
# Epoch 125/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 38.0168 - val_loss: 75.2677
# Epoch 126/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 35.9408 - val_loss: 56.8374
# Epoch 127/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 39.5143 - val_loss: 55.4344
# Epoch 128/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 39.7041 - val_loss: 61.3690
# Epoch 129/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 37.1280 - val_loss: 55.0477
# Epoch 130/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 37.3218 - val_loss: 55.1136
# Epoch 131/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 41.2848 - val_loss: 55.3159
# Epoch 132/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 37.1313 - val_loss: 55.5424
# Epoch 133/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 40.8996 - val_loss: 50.0464
# Epoch 134/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 36.4420 - val_loss: 58.3425
# Epoch 135/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 40.5235 - val_loss: 51.0799
# Epoch 136/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 35.7147 - val_loss: 50.3402
# Epoch 137/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 38.2737 - val_loss: 49.4631
# Epoch 138/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 36.4788 - val_loss: 52.0090
# Epoch 139/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 33.0198 - val_loss: 54.8850
# Epoch 140/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 35.2132 - val_loss: 50.2882
# Epoch 141/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 37.7368 - val_loss: 50.4529
# Epoch 142/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 35.2136 - val_loss: 54.5645
# Epoch 143/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 41.4887 - val_loss: 52.5424
# Epoch 144/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 36.6145 - val_loss: 54.2533
# Epoch 145/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 37.1163 - val_loss: 51.5475
# Epoch 146/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 39.6784 - val_loss: 55.0107
# Epoch 147/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 33.4994 - val_loss: 57.3563
# Epoch 148/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 39.2029 - val_loss: 61.2365
# Epoch 149/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 35.0885 - val_loss: 72.4850
# Epoch 150/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 35.8279 - val_loss: 55.1776
# Epoch 151/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 37.5013 - val_loss: 66.9799
# Epoch 152/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 37.1094 - val_loss: 55.6725
# Epoch 153/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 39.6063 - val_loss: 53.0838
# Epoch 154/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 40.8293 - val_loss: 53.1652
# Epoch 155/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 32.9901 - val_loss: 57.6736
# Epoch 156/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 35.6895 - val_loss: 67.5798
# Epoch 157/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 40.6070 - val_loss: 59.5955
# Epoch 158/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 38.0949 - val_loss: 50.4748
# Epoch 159/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 33.4418 - val_loss: 55.0950
# Epoch 160/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 35.8773 - val_loss: 62.9572
# Epoch 161/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 35.3872 - val_loss: 66.4935
# Epoch 162/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 48.1683 - val_loss: 85.0120
# Epoch 163/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 41.4762 - val_loss: 98.7767
# Epoch 164/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 44.5180 - val_loss: 56.0934
# Epoch 165/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 39.5651 - val_loss: 56.0091
# Epoch 166/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 37.0585 - val_loss: 61.9299
# Epoch 167/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 38.2160 - val_loss: 55.4608
# Epoch 168/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 33.9940 - val_loss: 61.9360
# Epoch 169/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 34.8691 - val_loss: 56.2041
# Epoch 170/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 34.2061 - val_loss: 75.3944
# Epoch 171/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 35.7826 - val_loss: 66.0191
# Epoch 172/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 34.2766 - val_loss: 61.5748
# Epoch 173/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 43.9595 - val_loss: 55.5446
# Epoch 174/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 34.5552 - val_loss: 52.3155
# Epoch 175/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 35.1191 - val_loss: 50.2098
# Epoch 176/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 39.4621 - val_loss: 54.8176
# Epoch 177/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 38.6161 - val_loss: 53.8170
# Epoch 178/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 38.0768 - val_loss: 51.6899
# Epoch 179/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 32.1875 - val_loss: 58.6201
# Epoch 180/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 36.8753 - val_loss: 56.3569
# Epoch 181/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 32.9813 - val_loss: 58.7364
# Epoch 182/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 30.6321 - val_loss: 63.6872
# Epoch 183/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 32.4032 - val_loss: 56.8530
# Epoch 184/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 36.6118 - val_loss: 52.3251
# Epoch 185/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 36.8130 - val_loss: 52.3450
# Epoch 186/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 35.8621 - val_loss: 58.2548
# Epoch 187/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 37.9042 - val_loss: 52.8625
# Epoch 188/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 29.6959 - val_loss: 51.5209
# Epoch 189/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 30.5000 - val_loss: 53.5962
# Epoch 190/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 34.4803 - val_loss: 52.9510
# Epoch 191/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 38.0723 - val_loss: 63.6222
# Epoch 192/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 30.0578 - val_loss: 47.1458
# Epoch 193/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 32.7642 - val_loss: 50.3592
# Epoch 194/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 30.6678 - val_loss: 62.1396
# Epoch 195/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 32.0882 - val_loss: 62.9805
# Epoch 196/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 32.8784 - val_loss: 51.0951
# Epoch 197/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 42.8172 - val_loss: 52.4366
# Epoch 198/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 34.1978 - val_loss: 54.6370
# Epoch 199/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 37.1149 - val_loss: 57.4969
# Epoch 200/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 34.9686 - val_loss: 54.8519

# %%
# make predictions on the testing data
print("[INFO] predicting house prices...")
preds = model.predict(testImagesX)

# compute the difference between the *predicted* house prices and the
# *actual* house prices, then compute the percentage difference and
# the absolute percentage difference
diff = preds.flatten() - testY
percentDiff = (diff / testY) * 100
absPercentDiff = np.abs(percentDiff)

# compute the mean and standard deviation of the absolute percentage
# difference
mean = np.mean(absPercentDiff)
std = np.std(absPercentDiff)

# finally, show some statistics on our model
from babel.numbers import format_currency
print("[INFO] avg. house price: {}, std house price: {}".format(
	format_currency(df["price"].mean(), 'USD', locale='en_US'),
	format_currency(df["price"].std(), 'USD', locale='en_US')))
# Out:
# [INFO] predicting house prices...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# [INFO] avg. house price: $533,388.27, std house price: $493,403.08

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Compute MAE
mae = mean_absolute_error(testY, preds.flatten())

# Calculate RMSE manually
mse = mean_squared_error(testY, preds.flatten())
rmse = np.sqrt(mse)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Mean Absolute Error (MAE): 0.04
# Root Mean Squared Error (RMSE): 0.06
